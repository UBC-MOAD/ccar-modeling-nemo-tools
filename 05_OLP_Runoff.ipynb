# %%
#import copy
import glob
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from __future__ import division
from __future__ import print_function
from mpl_toolkits.basemap import cm
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.basemap import shiftgrid
% matplotlib inline

# %%
gridT_obj=glob.glob('_data/RUNOFF*1m*grid_T.nc')
print("found file: \n{}".format(gridT_obj))
# Out:
# found file:
# ['_data/RUNOFF_test_run_1m_20100101_20101231_grid_T.nc']

# %%
gridT=nc.Dataset(gridT_obj[0])

# %%
freshwater=gridT.variables['freshwater'][:]

# %%
freshwater.shape
# Out:
# (12, 53, 142)

# %%
sst=gridT.variables['sosstsst'][:]

# %%
sst.shape
# Out:
# (12, 53, 142)

# %%
latitude=gridT.variables['nav_lat'][:]
longitude=gridT.variables['nav_lon'][:]

# %%
freshwater.min()
# Out:
# masked

# %%
#clevs=[0, 10, 50, 100, 1000]
rlon=81;
rlat=73;

fig=plt.figure(figsize=(12, 12))
proj=Basemap(projection='npstere', resolution='c', \
            boundinglat=50, lon_0=90, round=True)
ax=plt.gca()
## define parallels and meridians to draw.
parallels=np.arange(-90, 90, 15)
meridians=np.arange(0, 360, 60)
proj.drawparallels(parallels, labels=[1, 1, 1, 1],\
                  fontsize=10, latmax=90)
proj.drawmeridians(meridians, labels=[1, 1, 1, 1],\
                  fontsize=10, latmax=90)
# draw coast & fill continents
#proj.fillcontinents(color=[0.5, 0.5, 0.5], lake_color=None) # coral
proj.drawcoastlines(linewidth=2.0, linestyle='-', color='k')
#proj.drawrivers(linewidth=1.5, linestyle='-', color='b')
#proj.drawlsmask(land_color='k', ocean_color='None', lsmask=None)
# compute native x,y coordinates of grid.
x, y=proj(longitude, latitude)
rx, ry=proj(rlon, rlat)
proj.plot(rx, ry, 'ro')
#CS=proj.contourf(x, y, runoff[0, :, :], clevs, cmap=plt.cm.PiYG) # RdBu_r
#CS=proj.pcolormesh(x, y, freshwater[2, :, :], vmin=0, vmax=10000)
#CBar=proj.colorbar(CS, location='right', size='5%', pad='10%')

# %%
5475/3
# Out:
# 1825.0
