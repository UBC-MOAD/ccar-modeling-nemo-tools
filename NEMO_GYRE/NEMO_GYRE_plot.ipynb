# %% [markdown]
# #Objectives
# * This notebook provides examples which focused on the analysis (in annual mean values) and visulation of the output file from **NEMO_GYRE** configurtion. The output files required for this notebook including:
#         GYRE1_20000101_20001230_1M_grid_T.nc
#         GYRE1_20000101_20001230_1M_grid_U.nc
#         GYRE1_20000101_20001230_1M_grid_V.nc
#         GYRE1_20000101_20001230_1M_grid_W.nc

# %% [markdown]
# # Contents

# %% [markdown]
# 1. [**Import modules & tools**](#Import-modules-&-tools)
# 1. [**Read data files**](#Read-data-files)
#   2. [File info](#File_info)
#   2. [Read \*.nc files](#Read-*.nc-files)
#   2. ["Delete edge"](#"Delete-edge")
# 1. [**Surface plot**](#Surface-plot)
#   2. [Get surface data & mask data](#Get-surface-data-&-mask-data)
#   2. [SST plot](#SST-plot)
#   2. [Surface currents](#Surface-currents)
#   2. [Currents on 200m depth](#Currents-on-200m-depth)
# 1. [**Plot profile**](#Plot-profile)
#   2. [Profile location](#Profile-location)
#   2. [Get profile data & mask data](#Get-profile-data-&-mask-data)
#   2. [Temperature profile](#Temperature-profile)
#   2. [Vertical circulation](#Vertical-circulation)
# 1. [**Some useful things about "ticks"**](#*Some-useful-things-about-"ticks")

# %% [markdown]
# # Import modules & tools

# %%
import os
import copy
import glob
import math
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from __future__ import division
from __future__ import print_function
from mpl_toolkits.basemap import cm
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.basemap import shiftgrid
% matplotlib inline

# %%
__author__   = 'Yingkai Sha & CCAR Modeling Team'
__email__    = 'yingkai@eos.ubc.ca'

# %% [markdown]
# # Read data files

# %% [markdown]
# ## File info.

# %% [markdown]
# *Make sure that netCDF files are in the current directly

# %%
# file info
nc_filename=glob.glob('*.nc')
print("found *.nc file: \n{}".format(nc_filename))
# Out:
# found *.nc file:
# ['GYRE1_20000101_20001230_1M_grid_T.nc', 'GYRE1_20000101_20001230_1M_grid_U.nc', 'GYRE1_20000101_20001230_1M_grid_V.nc', 'GYRE1_20000101_20001230_1M_grid_W.nc']

# %%
T=nc.Dataset(nc_filename[0])
U=nc.Dataset(nc_filename[1])
V=nc.Dataset(nc_filename[2])
W=nc.Dataset(nc_filename[3])

# %%
print(T.ncattrs())
print('============================================================')
print(T.variables)
# Out:
# [u'Conventions', u'file_name', u'production', u'TimeStamp']
# ============================================================
# OrderedDict([(u'nav_lon', <netCDF4.Variable object at 0x000000000B1B5288>), (u'nav_lat', <netCDF4.Variable object at 0x000000000B1B51F8>), (u'deptht', <netCDF4.Variable object at 0x000000000B1B53A8>), (u'time_counter', <netCDF4.Variable object at 0x000000000B1B5438>), (u'votemper', <netCDF4.Variable object at 0x000000000B1B54C8>), (u'vosaline', <netCDF4.Variable object at 0x000000000B1B5558>), (u'sosstsst', <netCDF4.Variable object at 0x000000000B1B55E8>), (u'sosaline', <netCDF4.Variable object at 0x000000000B1B5678>), (u'sossheig', <netCDF4.Variable object at 0x000000000B1B5708>), (u'sowaflup', <netCDF4.Variable object at 0x000000000B1B5798>), (u'sowaflcd', <netCDF4.Variable object at 0x000000000B1B5828>), (u'sosalflx', <netCDF4.Variable object at 0x000000000B1B58B8>), (u'sohefldo', <netCDF4.Variable object at 0x000000000B1B5948>), (u'soshfldo', <netCDF4.Variable object at 0x000000000B1B59D8>), (u'somxl010', <netCDF4.Variable object at 0x000000000B1B5A68>), (u'somixhgt', <netCDF4.Variable object at 0x000000000B1B5AF8>), (u'soicecov', <netCDF4.Variable object at 0x000000000B1B5B88>), (u'sohefldp', <netCDF4.Variable object at 0x000000000B1B5C18>), (u'sowafldp', <netCDF4.Variable object at 0x000000000B1B5CA8>), (u'sosafldp', <netCDF4.Variable object at 0x000000000B1B5D38>), (u'sobowlin', <netCDF4.Variable object at 0x000000000B1B5DC8>)])

# %% [markdown]
# ## Read *.nc files

# %%
# Geo. Info.
depth=T.variables['deptht'][:]
latitude=T.variables['nav_lat'][:]
longitude=T.variables['nav_lon'][:]
print('==============================')
print('Latitude range: {} ~ {}'.format(np.min(np.min(latitude)), np.max(np.max(latitude))))
print('Longitude range: {} ~ {}'.format(np.min(np.min(longitude)), np.max(np.max(longitude))))
#print('Depth: \n{}'.format(depth)) 
# temperature & salinity
vot=T.variables['votemper'][:]
sst=T.variables['sosstsst'][:]
vos=T.variables['vosaline'][:]
sos=T.variables['sosaline'][:]
# velosity
u_NE=U.variables['vozocrtx'][:]
v_NW=V.variables['vomecrty'][:]
w=W.variables['vovecrtz'][:]
# print size
print('==============================')
print('Oringal data size: {}'.format(vot.shape))
# annual mean
vot=np.mean(vot, axis=0)
sst=np.mean(sst, axis=0)
vos=np.mean(vos, axis=0)
sos=np.mean(sos, axis=0)
u_NE=np.mean(u_NE, axis=0)
v_NW=np.mean(v_NW, axis=0)
w=np.mean(w, axis=0)
print('Annual mean data size: {}'.format(vot.shape))
# correct the velosity <--------------------------------- ?
u=np.sqrt(1/2)*(u_NE-v_NW)
v=np.sqrt(1/2)*(u_NE+v_NW)
# Out:
# ==============================
# Latitude range: 14.8450098038 ~ 49.8954620361
# Longitude range: -85.6740493774 ~ -50.6235961914
# ==============================
# Oringal data size: (12L, 31L, 22L, 32L)
# Annual mean data size: (31L, 22L, 32L)

# %% [markdown]
# ## "Delete edge"

# %% [markdown]
# The 1st (sometimes even 2nd) row and column in the output files are unreliable, due to the finite difference method in **NEMO_GYRE**. So we need to delete data's boundary.

# %%
def delete_edge(data, order=[1, 1, 1, 1]):
    
    ''' 
    Delete the edge of input data
    ----- data: input data, originally designed for Lat*Lon;
    ----- order: how many rows/columns you'd like to delete in 4 edges;

                order(2)
              -----------
             |           |
    order(1) |           | order(3)
             |           |
              -----------
                order(4)

    ----- Note: delete means NaN. You can mask NaN if you want.
    '''
    import numpy as np
    
    #LatN=np.size(data, 0) --> 22
    #LonN=np.size(data, 1) --> 32
    
    data[:, 0:order[0]]=np.nan
    data[0:order[1], :]=np.nan
    data[:, (np.size(data, 1)-order[2]):np.size(data, 1)]=np.nan
    data[(np.size(data, 0)-order[3]):np.size(data, 0), :]=np.nan

    return data

# %% [markdown]
# Test if delete_edge works well

# %%
# e.g. sst=delete_edge(sst, [1, 1, 1, 1])
print('Test')
print('==============================')
print(sst.shape)
test=delete_edge(sst, [1, 1, 1, 1])
print(sst[0:22, 0])
#sst[21:22, :]
print('==============================')
# complete
print('Complete')
# Out:
# Test
# ==============================
# (22L, 32L)
# [ nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan  nan
#   nan  nan  nan  nan  nan  nan  nan]
# ==============================
# Complete

# %% [markdown]
# # Surface plot

# %% [markdown]
# ## Get surface data & mask data

# %%
# delete horizontal 4 edges 
#(the bottom will be deleted in section 4)
# =================================== #
# sst
sst=delete_edge(sst, [1, 1, 1, 1])
# vot
for i in range(0, np.size(vot, 0)):
    temp=vot[i, :, :]
    temp=delete_edge(temp, [1, 1, 1, 1])
    vot[i, :, :]=temp
# u
for i in range(0, np.size(u, 0)):
    temp=u[i, :, :]
    temp=delete_edge(temp, [1, 1, 2, 2])
    u[i, :, :]=temp
# v
for i in range(0, np.size(v, 0)):
    temp=v[i, :, :]
    temp=delete_edge(temp, [1, 1, 2, 2])
    v[i, :, :]=temp
# w
for i in range(0, np.size(w, 0)):
    temp=w[i, :, :]
    temp=delete_edge(temp, [1, 1, 2, 2])
    w[i, :, :]=temp
# =================================== #
# get valuable, and mask for surface plot
# sst
sst_ma=np.ma.masked_where(np.isnan(sst), sst)
# surface current
u_surface=u[0, :, :]
v_surface=v[0, :, :]
u_s_ma=np.ma.masked_where(np.isnan(u_surface), u_surface)
v_s_ma=np.ma.masked_where(np.isnan(v_surface), v_surface)
# 200m depth
u_200=u[11, :, :]
v_200=v[11, :, :]
u_200_ma=np.ma.masked_where(np.isnan(u_200), u_200)
v_200_ma=np.ma.masked_where(np.isnan(v_200), v_200)

# %% [markdown]
# ## SST plot

# %%
# Common
latlim=[10, 50]
lonlim=[-85, -45]
clevs=[15, 16, 17, 18, 19, 20, 21, 21.5, 22, 22.5, 23, 23.5, 24, 24.5, 25, 26] # degC
# Figure
fig=plt.figure(figsize=(8, 8))
ax=fig.add_axes([0.1, 0.1, 0.8, 0.8])
map=Basemap(projection='lcc',\
            lat_1=30, lat_2=60, lat_0=45, lon_0=-65,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')
# draw coast line
map.drawcoastlines(linewidth=1, color='k') #map.drawcountries, map.drawstates, map.fillcontinents
# draw parallels.
parallels = np.arange(0, 90, 10)
map.drawparallels(parallels, labels=[1, 0, 0, 0],fontsize=10)
# draw meridians
meridians = np.arange(180, 360, 10)
map.drawmeridians(meridians, labels=[0,0,0,1],fontsize=10)
# transfer from Lat/Lon to projected grid
x, y=map(longitude, latitude) 
# filled contour
CS=map.contourf(x, y, sst_ma, clevs, cmap=plt.cm.RdBu_r) # RdBu_r
#map.contour(x, y, sst_ma, clevs, colors=('k',), linewidth=1)
# colorbar
CBar=map.colorbar(CS, location='right', size='5%', pad='2%')
# label & title
CBar.set_label('Sea Surface Temperature ($\mathrm{^\circ C}$ )', fontsize=10)
ax.set_title('NEMO_GYRE_sosstsst', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ## Surface currents

# %%
# Common
latlim=[10, 50]
lonlim=[-85, -45]
speed=np.sqrt(u_s_ma*u_s_ma+v_s_ma*v_s_ma)
# Figure
fig=plt.figure(figsize=(8, 8))
ax=fig.add_axes([0.1, 0.1, 0.8, 0.8])
map=Basemap(projection='lcc',\
            lat_1=30, lat_2=60, lat_0=45, lon_0=-65,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')
# draw coast line
map.drawcoastlines(linewidth=1, color=[0.5, 0.5, 0.5]) #map.drawcountries, map.drawstates, map.fillcontinents
# draw parallels.
parallels = np.arange(0, 90, 10)
map.drawparallels(parallels, labels=[1, 0, 0, 0],fontsize=10)
# draw meridians
meridians = np.arange(180, 360, 10)
map.drawmeridians(meridians, labels=[0,0,0,1],fontsize=10)
# transform lat/lon to projection grid.
x, y=map(longitude, latitude)
# streamline
Q=map.quiver(x, y, u_s_ma, v_s_ma, width=0.0025, scale=1)
# make quiver key.
Qlabel=plt.quiverkey(Q, 0.2, 0.6, 0.05, '0.05 m/s', labelpos='W') # width, height, scale, label, position
#width=5*speed/speed.max() # '5' is the scale
#map.streamplot(x, y, u_s_ma, v_s_ma, density=0.6, color='k', linewidth=width)
# title
ax.set_title('NEMO_GYRE_surface_currents', fontsize=12, fontweight='bold')
plt.show()
# Out:
# F:\Anaconda\lib\site-packages\numpy\ma\core.py:807: RuntimeWarning: invalid value encountered in less
#   return umath.less(x, self.critical_value)

# %% [markdown]
# ## Currents on 200m depth

# %%
# Common
latlim=[10, 50]
lonlim=[-85, -45]
speed=np.sqrt(u_200_ma*u_200_ma+v_200_ma*v_200_ma)
# Figure
fig=plt.figure(figsize=(8, 8))
ax=fig.add_axes([0.1, 0.1, 0.8, 0.8])
map=Basemap(projection='lcc',\
            lat_1=30, lat_2=60, lat_0=45, lon_0=-65,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')
# draw coast line
map.drawcoastlines(linewidth=1, color=[0.5, 0.5, 0.5]) #map.drawcountries, map.drawstates, map.fillcontinents
# draw parallels.
parallels = np.arange(0, 90, 10)
map.drawparallels(parallels, labels=[1, 0, 0, 0], fontsize=10)
# draw meridians
meridians = np.arange(180, 360, 10)
map.drawmeridians(meridians, labels=[0,0,0,1],fontsize=10)
# transform vlat/lon to projection grid.
x, y=map(longitude, latitude)
# streamline
Q=map.quiver(x, y, u_200_ma, v_200_ma, width=0.0025, scale=1)
# make quiver key.
Qlabel=plt.quiverkey(Q, 0.2, 0.6, 0.05, '0.05 m/s', labelpos='W')
#width=5*speed/speed.max() # '5' is the scale
#ax.streamplot(x, y, u_ma, v_ma, density=0.6, color='k', linewidth=width)
# title
ax.set_title('NEMO_GYRE_currents_200m_depth', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# # Profiles

# %% [markdown]
# ## Profile location

# %% [markdown]
# Here we creat our profile on [:, 4] grid, it crosses the center of the Gyre

# %%
# Where we make the profile
lat_sec=latitude[:, 4]
lon_sec=longitude[:, 4]

# %% [markdown]
# *Noted that, the profile here are not purely zonal or meridional, it is changing in both directions.

# %%
# Figure
fig=plt.figure(figsize=(8, 8))
ax=fig.add_axes([0.1, 0.1, 0.8, 0.8])
map=Basemap(projection='lcc',\
            lat_1=30, lat_2=60, lat_0=45, lon_0=-65,\
            llcrnrlon=lonlim[0], llcrnrlat=latlim[0],\
            urcrnrlon=lonlim[1], urcrnrlat=latlim[1],\
            resolution='l')
# draw coast line
map.drawcoastlines(linewidth=1, color=[0.5, 0.5, 0.5])
# draw parallels.
parallels = np.arange(0, 90, 10)
map.drawparallels(parallels, labels=[1, 0, 0, 0],fontsize=10)
# draw meridians
meridians = np.arange(180, 360, 10)
map.drawmeridians(meridians, labels=[0,0,0,1],fontsize=10)
# transform vlat/lon to projection grid.
x, y=map(longitude, latitude)
x_sec, y_sec=map(lon_sec, lat_sec)
# plot sectionline, then data point
ax.plot(x_sec, y_sec, linewidth=8, color=[0.75, 0.75, 0.75], label='transit line')
ax.plot(x, y, color='k', linestyle='none', marker='o', markersize=4, linewidth=1)
ax.legend(fontsize=12)
ax.set_title('Profile_Location', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ## Get profile data & mask data

# %%
# Temperature profile
pro_t=vot[:, :, 4]
# check the size
print('Size of pro_t: {}'.format(pro_t.shape))
# Vertical circulation
pro_u=u[:, :, 4]
pro_v=v[:, :, 4]
pro_w=w[:, :, 4]
# check the size
print('Size of pro_u: {}\nSize of pro_v: {}\nSize of pro_w: {}'.format(pro_u.shape, pro_v.shape, pro_w.shape))
# Lat/Lon Grid
x, z=np.meshgrid(lat_sec, depth)
print('Size of x (in latitude): {}'.format(x.shape))
print('Size of z (in depth): {}'.format(z.shape))
# Out:
# Size of pro_t: (31L, 22L)
# Size of pro_u: (31L, 22L)
# Size of pro_v: (31L, 22L)
# Size of pro_w: (31L, 22L)
# Size of x (in latitude): (31L, 22L)
# Size of z (in depth): (31L, 22L)

# %% [markdown]
# We need to delete the bottom edge of profile data for a similar reason as <a href='#"Delete-edge"'>section 2.C</a> tells

# %%
# Delete the bottom edge 
pro_t=delete_edge(pro_t, [0, 0, 0, 1])
pro_t_ma=np.ma.masked_where(np.isnan(pro_t), pro_t)
pro_u=delete_edge(pro_u, [0, 0, 0, 1])
pro_u_ma=np.ma.masked_where(np.isnan(pro_u), pro_u)
pro_v=delete_edge(pro_v, [0, 0, 0, 1])
pro_v_ma=np.ma.masked_where(np.isnan(pro_v), pro_v)
pro_w=delete_edge(pro_w, [0, 0, 0, 1])
pro_w_ma=np.ma.masked_where(np.isnan(pro_w), pro_w)

# %% [markdown]
# See the range of profile data

# %%
print('Latitude range: {} ~ {}'.format(lat_sec[0], lat_sec[-1]))
print('Depth range: {} ~ {}'.format(depth[0], depth[-1]))
# Out:
# Latitude range: 17.5411987305 ~ 31.696187973
# Depth range: 4.97526550293 ~ 4451.25927734

# %% [markdown]
# ## Temperature profile

# %%
# Common
clevs=[3, 6, 9, 12, 15, 18, 21, 24, 27]
# Figure
fig=plt.figure(figsize=(8, 8))
ax=plt.gca()
ax.set_xlim(lat_sec[0]+1, lat_sec[-1]-1)
ax.set_ylim(depth[0]+20, 1500)
ax.invert_yaxis()
ax.xaxis.set_tick_params(size=0)
ax.yaxis.set_tick_params(size=0)
ax.set_xlabel('Latitude ($^\circ N$)')
ax.set_ylabel('Depth (m)')
#CS=plt.contourf(x, z, pro_u_ma)
CS=plt.contourf(x, z, pro_t_ma, clevs, cmap=plt.cm.RdBu_r)
plt.contour(x, z, pro_t, clevs, colors = ('k',), linewidth=1)
CBar=plt.colorbar(CS)
# label & title
CBar.set_label('Temperature ($\mathrm{^\circ C}$ )', fontsize=10)
ax.set_title('NEMO_GYRE_temperature_profile', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ## Vertical circulation

# %%
# Common
clevs=np.array([-4, -3, -2, -1, 1, 2, 3, 4])*1e-6
# Figure
fig=plt.figure(figsize=(8, 8))
ax=plt.gca()
ax.set_xlim(lat_sec[0]+1, lat_sec[-1]-1)
ax.set_ylim(depth[0], 1500)
ax.invert_yaxis()
ax.xaxis.set_tick_params(size=0)
ax.yaxis.set_tick_params(size=0)
ax.set_xlabel('Latitude ($^\circ N$)')
ax.set_ylabel('Depth (m)')
# contour w
CS=plt.contour(x, z, pro_w_ma, clevs, colors = ([0.5, 0.5, 0.5],), linewidth=1.5)
# label the contour
labels = ['vertical velosity (w)']
CS.collections[-1].set_label(labels[0])
# Quiver
Q=plt.quiver(x, z, pro_u_ma, pro_v_ma, width=0.0025, scale=0.5, color='k')
# make quiver key.
Qlabel=plt.quiverkey(Q, 0.15, 0.1, 0.05, '0.01 m/s', labelpos='W')
# legend
plt.legend(loc='lower left', fontsize=12)
ax.set_title('NEMO_GYRE_vertical_circulation', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# # *Some useful things about "ticks"

# %% [raw]
# ax=plt.gca()
# ax.set_xlim()
# ax.set_ylim()
# ax.invert_yaxis()
# ax.yaxis.tick_left()
# ax.yaxis.set_tick_params(size=0)
# plt.setp(ax.get_yticklabels(), visible=False)
# plt.tick_params(\
#     axis='x',          # changes apply to the x-axis
#     which='both',      # both major and minor ticks are affected
#     bottom='off',      # ticks along the bottom edge are off
#     top='off',         # ticks along the top edge are off
#     labelbottom='off') # labels along the bottom edge are off
